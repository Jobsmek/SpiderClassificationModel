# %% [markdown]
# This includes the dataset gathered and provided by Dr.Heins of [total amount of spiders] spiders and more specifically [number of species] species.

# %%
# import necessary libraries 
import matplotlib.pyplot as plt
import numpy as np
import torchvision
import torch 
import torchvision.transforms as transform
from sklearn import *
import os

# later import sklearn and more specific library modules

# %%
# test torch 
x = torch.rand(5,3)
print(x)
# Out:
# tensor([[0.3736, 0.4490, 0.4577],
#         [0.6182, 0.1650, 0.9730],
#         [0.9258, 0.9773, 0.7367],
#         [0.8601, 0.4645, 0.9787],
#         [0.0198, 0.2222, 0.0118]])

# %% [markdown]
# ### Image loading and preparation
#
# We'll have to order/organize and load the images so that they can be more easily split into training and test sets and for the classifier to function. Create an image bin and each folder inside it will be of a singel species. Something like this:
#
# ![image.png](attachment:image.png)
#
# The bottom folders would be the species.

# %%
class Dataset(object):
   def __getitem__(self, index):
     raise NotImplementedError
   def __len__(self):
     raise NotImplementedError

# %% [markdown]
# ### Labeling
#
# Step necessary in order to correctly identify species labels as a DataBlock/blueprint method. Dr.Heins greatly helped in speeding up this process.

# %% [markdown]
# ### Preprocessing images
#
# This step is taken in order to derive more data from the images gathered by resizing, cropping, rotating,"squishing", or flipping.

# %% [markdown]
# ### Splitting dataset into Trainining, Validation(dev), and Test set

# %% [markdown]
# First, the dataset will be split using indexing. Next, scikit-learn's train_test_split()
# function will be used for the same purpose, thereby achieving the same result with both approaches.

# %% [markdown]
# Start by printing out the shape of the dataset in order to determine the split ratio of the test, dev, and training sets. 60:20:20 or other kind of data split.

# %% [markdown]
# Shuffle the dataset

# %% [markdown]
# Use indexing to split the shuffled dataset into the three sets for both the features and the target data:

# %% [markdown]
# Print the shapes of all three sets in order to see the process

# %% [markdown]
# Import the train_test_split() function from sklearn.model_selection module

# %% [markdown]
# Split the shuffled dataset.
# Print out the shape of all three sets one more time after shuffling twice essentially.
